# %%
# u17
a = int(input())
while a >= 1350 :
    a -= 1350
    print(a)
# Out:
# 8650
# 7300
# 5950
# 4600
# 3250
# 1900
# 550

# %%
# u18
start , stop = map(int, input().split())

i = start

while True:
    if '3' == str(i)[-1]:
        i += 1
        continue
    if i > stop:
        break
    print(i, end=' ')
    i += 1
# Out:
# 1 2 4 5 6 7 8 9 10 11 12 14 15 16 17 18 19 20

# %%
# u19

a = int(input())
b = 1
for i in range(1, a+1):
    print((' ' * (a-i))+ '*' * b )
    b += 2
# Out:
#   *
#  ***
# *****

# %%
# u23
a, b = map(int, input().split())

mines = []
for i in range(b):
    mines.append(list(input()))


pad_mines = [['.' for _ in range(a+2)] for _ in range(b+2)]
for i in range(a):
    for j in range(b):
        pad_mines[i+1][j+1] = mines[i][j]

for q in range(1, a+1):        # 1, 2, 3
    for w in range(1, b+1):
            count = 0
            if pad_mines[q][w] == '.':
                if pad_mines[q-1][w-1] == '*':
                    count += 1
                if pad_mines[q-1][w] == '*':
                    count += 1
                if pad_mines[q-1][w+1] == '*':
                    count += 1
                if pad_mines[q][w-1] == '*':
                    count += 1
                if pad_mines[q][w+1] == '*':
                    count += 1
                if pad_mines[q+1][w-1] == '*':
                    count += 1
                if pad_mines[q+1][w] == '*':
                    count += 1
                if pad_mines[q+1][w+1] == '*':
                    count += 1
                mines[q-1][w-1] = count
for row in mines:
    for elem in row:
        print(elem, end='')
    print()
# Out:
# 01*21
# 123*1
# 2*532
# 3***1
# *4*31

# %%
# u 24-5
import string
a = input()
b = a.split(' ')
list1 = []
for i in b:
    list1.append(i.strip(string.punctuation))

count = 0

for i in list1:
    if 'the' == i:
        count += 1
print(count)
# Out:
# 6

# %%
# u24-6
a = input()
b = a.split(';')
c = list(map(int, b))
c.sort(reverse=True)
c
for i in c:
    print(format(i, ',d').rjust(9))
# Out:
# 1,304,000
#   367,500
#   250,000
#   158,000
#   128,500
#    83,000
#    59,200
#    51,900

# %%
# u25
keys = input().split()
values = map(int, input().split())
 
x = dict(zip(keys, values))

str = ( k for k, v in x.items() if v == 30 )

x.pop(str)
x.pop('delta')



print(x)
# Out:
# {'alpha': 10, 'bravo': 20}

# %%
# u26
x, y = map(int, input().split())
num = 1
a = set()
b = set()
while True:
    if num > x or num > y:
        break
    if x % num == 0:
        a.add(num)
    if y % num == 0:
        b.add(num)
    num += 1

divisor = a & b
 
result = 0
if type(divisor) == set:
    result = sum(divisor)
 
print(result)
# Out:
# 18
